# %%
def closest_number(n,m):
    temp=n
    counter=0
    brek=0
    inc_num=0
    dec_brek=0;inc_brek=0
    counter=0
    for it in range(abs(m)+1,0,-1):
        if it%2!=0:
            counter+=1

#         if it%2!=0:
        dec_num=temp-counter
        #print("dec",dec_num)
        if(dec_num%m==0):
            dec_num
            dec_brek=1
        

#         else:
        inc_num=temp+counter
        #print("inc",inc_num)
        if(inc_num%m==0):
            inc_num
            inc_brek=1

        if dec_brek==1 and inc_brek==1 and abs(dec_num)>abs(inc_num):
            return dec_num
        elif dec_brek==1 and inc_brek==1 and abs(inc_num)>abs(dec_num):
            return inc_num
        elif dec_brek==1:
            return dec_num
        elif inc_brek==1:
            return inc_num
        
    return 0

# %%
inpu=int(input())
for iteration in range(inpu):
    n,m=map(int,input().split())
    if n%m==0:
        print(n)
    else:
        print(closest_number(n,m))
# Out:
# 1
# 221 134
# dec 220
# inc 222
# dec 220
# inc 222
# dec 219
# inc 223
# dec 219
# inc 223
# dec 218
# inc 224
# dec 218
# inc 224
# dec 217
# inc 225
# dec 217
# inc 225
# dec 216
# inc 226
# dec 216
# inc 226
# dec 215
# inc 227
# dec 215
# inc 227
# dec 214
# inc 228
# dec 214
# inc 228
# dec 213
# inc 229
# dec 213
# inc 229
# dec 212
# inc 230
# dec 212
# inc 230
# dec 211
# inc 231
# dec 211
# inc 231
# dec 210
# inc 232
# dec 210
# inc 232
# dec 209
# inc 233
# dec 209
# inc 233
# dec 208
# inc 234
# dec 208
# inc 234
# dec 207
# inc 235
# dec 207
# inc 235
# dec 206
# inc 236
# dec 206
# inc 236
# dec 205
# inc 237
# dec 205
# inc 237
# dec 204
# inc 238
# dec 204
# inc 238
# dec 203
# inc 239
# dec 203
# inc 239
# dec 202
# inc 240
# dec 202
# inc 240
# dec 201
# inc 241
# dec 201
# inc 241
# dec 200
# inc 242
# dec 200
# inc 242
# dec 199
# inc 243
# dec 199
# inc 243
# dec 198
# inc 244
# dec 198
# inc 244
# dec 197
# inc 245
# dec 197
# inc 245
# dec 196
# inc 246
# ...

# %%
#https://practice.geeksforgeeks.org/problems/closest-number/0

# %%
-2%2
# Out:
# 0
